# %%
import pandas as pd
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
dataset.isnull()
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0    False   False  False  False  False  False  False     False     False
# 1    False   False  False  False  False  False  False     False     False
# 2    False   False  False  False  False  False  False     False     False
# 4    False   False  False  False  False  False  False     False     False
# 7    False   False  False  False  False  False  False     False     False
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 209  False   False  False  False  False  False  False     False     False
# 210  False   False  False  False  False  False  False     False     False
# 211  False   False  False  False  False  False  False     False     False
# 212  False   False  False  False  False  False  False     False     False
# 213  False   False  False  False  False  False  False     False     False
#
#      workex  etest_p  specialisation  mba_p  status  salary
# ...

# %%
#count the null values columns

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#drop the missing row

# %%
#inplace=True with caution as it modifies the original DataFrame and does not return any value
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
#Replace the missing value with '0'

# %%
dataset["salary"].fillna(0,inplace=True)
# Out:
# C:\Users\jegat\AppData\Local\Temp\ipykernel_18324\2080798296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#replace the missing value with mean

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)
# Out:
# C:\Users\jegat\AppData\Local\Temp\ipykernel_18324\2561448817.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#https://scikit-learn.org/stable/modules/impute.html

# %%
#import numpy as np
#from sklearn.impute import SimpleImputer
#imp = SimpleImputer(missing_values=np.nan, strategy='mean')
#imp.fit(dataset[quan])

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        print(columnName)
        if(dataset[columnName].dtype=='O'):
            print("qual")
            qual.append(columnName)
        else:
            print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanqual(dataset)
# Out:
# sl_no
# quan
# gender
# qual
# ssc_p
# quan
# ssc_b
# qual
# hsc_p
# quan
# hsc_b
# qual
# hsc_s
# qual
# degree_p
# quan
# degree_t
# qual
# workex
# qual
# etest_p
# quan
# specialisation
# qual
# mba_p
# quan
# status
# qual
# salary
# quan
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan,qual=quanqual(dataset)
# Out:
# sl_no
# quan
# gender
# qual
# ssc_p
# quan
# ssc_b
# qual
# hsc_p
# quan
# hsc_b
# qual
# hsc_s
# qual
# degree_p
# quan
# degree_t
# qual
# workex
# qual
# etest_p
# quan
# specialisation
# qual
# mba_p
# quan
# status
# qual
# salary
# quan

# %%
dataset[quan]
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# 7        8  82.00  64.00     66.00     67.0  62.14  252000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 209    210  62.00  72.00     65.00     67.0  56.49  216000.0
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
#
# [148 rows x 7 columns]

# %%
import numpy as np
#change missing value,nun values of all columns using impute
from sklearn.impute import SimpleImputer
#for quantative data, using mean and median to change nun values 
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
# Out:
# SimpleImputer()

# %%
imp.fit(dataset[quan])
#dataset=imp.transform(dataset[quan])
# Out:
# SimpleImputer()

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
#for making table format first transform dataset into df
df=imp.transform(dataset[quan])
df=pd.DataFrame(df,columns=quan)

# %%
df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
#
# [148 rows x 7 columns]

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
#for qualtative data, using mode to change nun values 
imp = SimpleImputer(missing_values=np.nan, strategy= 'most_frequent')
imp.fit(dataset[qual])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
cata=imp.transform(dataset[qual])
cata=pd.DataFrame(cata,columns=qual)

# %%
cata
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# 4        M  Central  Central   Science   Sci&Tech    Yes        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 143      M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# 144      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 145      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 146      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 147      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
#
#      status
# 0    Placed
# 1    Placed
# 2    Placed
# 3    Placed
# 4    Placed
# ..      ...
# ...

# %%
cata=dataset[qual]

# %%
cata
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# 7        M  Central  Central   Science   Sci&Tech    Yes        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 209      M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
#
#      status
# 0    Placed
# 1    Placed
# 2    Placed
# 4    Placed
# 7    Placed
# ..      ...
# ...

# %%
#Concate quan-df and qual-cata
two=[df,cata]
preprocessed=pd.concat(two,axis=1)

# %%
preprocessed
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0      M  Central
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
#
# ...

# %%
preprocessed.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
#convert normal file to csv file
preprocessed.to_csv("PrePlacement.csv",index=False)
