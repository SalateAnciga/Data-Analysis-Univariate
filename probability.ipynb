# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
#visual repersentation 
import seaborn as sns

# %%
#NORMAL DISTRIBUTION 
#distplot function   is a function that combines a histogram and a kernel density estimation (KDE) plot to visualize the distribution of a single variable,
sns.distplot(dataset["ssc_p"])
# Out:
# C:\Users\jegat\AppData\Local\Temp\ipykernel_16128\4268137912.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["ssc_p"])
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
#in the above fig shapes like building is histogram,curve is a density

# %%
#PROBABILITY DENSITY FUNCTION

# %%
def get_pdf_prob(dataset,startrange,endrange):
    #Pyplot functionsused for creating a figure, plotting lines, and decorating the plot with labels.
    from matplotlib import pyplot
    #SciPy provides functions for working with the normal distribution,computing probability density functions (PDF), cumulative distribution functions (CDF)
    from scipy.stats import norm
    #Seaborn is a Python data visualization library built on top of Matplotlib. 
    import seaborn as sns
    #The distplot function  is used for univariate distribution of observations.kde means kernel distibution providing a smooth curve that represents the distribution of the data.
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    #Draw verticalline based on startrange,endrange with red color
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    #generate sample
    sample=dataset
    #calculator parameter
    #Calculate mean and standard Divation
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean-%.3f,Standard Deviation-%.3f'%(sample_mean,sample_std))
    #define distribution
    #norm() functionis used to make the  distribution
    dist=norm(sample_mean,sample_std)
    #sample probabilites for arange of outcomkes
    #create a list usind inliner for loop 
    values=[value for value in range(startrange,endrange)]
    #find probability distribution
    probabilites=[dist.pdf(value) for value in values]
    #find whole probabilities using sum()
    prob=sum(probabilites)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilites)))
    return prob

# %%
get_pdf_prob(dataset["ssc_p"],60,70)
# Out:
# Mean-71.721,Standard Deviation-8.715
# The area between range(60,70):0.3190485647827792
# C:\Users\jegat\AppData\Local\Temp\ipykernel_16128\3269425917.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# 0.3190485647827792

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from statsmodels) (2.2.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\jegat\anaconda3\envs\cluster\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)

# %%
#CUMMLATIVE DUSTRIBUTION

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset['ssc_p'])
ecdf(78)
# Out:
# 0.75

# %%
#STANDARD NORMAL DISTRIBUTION

# %%
def stdNBdist(dataset):
    #data visualation library for ex if you draw histogram you must import seaborn
    import seaborn as sns 
    #assign dataset into sample
    sample=dataset
    #calculate mean,Standard deviation
    sample_mean=sample.mean()
    sample_std=sample.std()
    #Take the corresponding data (ie) i from dataset & put into the list named as values
    values=[i for i in dataset]
    #calculate z_score value
    z_score=[((j-sample_mean)/sample_std) for j in values]
    #distplot function is used to find normal distribution.kde=True means draw the density curve
    sns.distplot(z_score,kde=True)
    #calculate mean of z_score.
    mean=sum(z_score)/len(z_score)
    print(mean)

# %%
stdNBdist(dataset["ssc_p"])
# Out:
# C:\Users\jegat\AppData\Local\Temp\ipykernel_16128\3184641268.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
# -1.251251354780244e-15
